# %% [markdown]
# # Database Table Explorer - Marketing Analytics Pipeline
#
# This notebook displays details of all tables across the pipeline databases:
# - **staging.db** - Derived tables (cleaned and standardized source data)
# - **warehouse.db** - Dimension and fact tables (dimensional model)
# - **business.db** - Business analysis tables (insights and analytics)
# - **metadata.db** - Pipeline metadata (execution logs and data quality)

# %%
import sqlite3
import pandas as pd
import os
from IPython.display import display, HTML

# %%
# Setup database paths
base_path = os.path.dirname(os.getcwd())  # Go up one level from notebooks
databases = {
    'staging': os.path.join(base_path, 'data', 'staging.db'),
    'warehouse': os.path.join(base_path, 'data', 'warehouse.db'), 
    'business': os.path.join(base_path, 'data', 'business.db'),
    'metadata': os.path.join(base_path, 'data', 'metadata.db')
}

print("Database paths:")
for name, path in databases.items():
    exists = "EXISTS" if os.path.exists(path) else "NOT FOUND"
    print(f"  {name}: {path} ({exists})")
# Out:
# Database paths:
#   staging: /Users/ashwindhanasamy/Documents/cave/HEC/marketing-analytics-pipeline/data/staging.db (EXISTS)
#   warehouse: /Users/ashwindhanasamy/Documents/cave/HEC/marketing-analytics-pipeline/data/warehouse.db (EXISTS)
#   business: /Users/ashwindhanasamy/Documents/cave/HEC/marketing-analytics-pipeline/data/business.db (EXISTS)
#   metadata: /Users/ashwindhanasamy/Documents/cave/HEC/marketing-analytics-pipeline/data/metadata.db (EXISTS)

# %%
def connect_to_database(db_name):
    """Connect to specified database"""
    db_path = databases.get(db_name)
    if db_path and os.path.exists(db_path):
        return sqlite3.connect(db_path)
    return None

def get_tables(conn):
    """Get list of tables in database"""
    cursor = conn.execute("SELECT name FROM sqlite_master WHERE type='table'")
    return [row[0] for row in cursor.fetchall()]

def get_table_info(conn, table_name):
    """Get table schema and row count"""
    # Get column information
    cursor = conn.execute(f"PRAGMA table_info({table_name})")
    columns = cursor.fetchall()
    
    # Get row count
    cursor = conn.execute(f"SELECT COUNT(*) FROM {table_name}")
    row_count = cursor.fetchone()[0]
    
    return columns, row_count

def get_sample_data(conn, table_name, limit=5):
    """Get sample data from table"""
    try:
        return pd.read_sql_query(f"SELECT * FROM {table_name} LIMIT {limit}", conn)
    except Exception as e:
        return pd.DataFrame({'Error': [str(e)]})

# %% [markdown]
# ## Staging Database (Derived Tables)
# Cleaned and standardized source data

# %%
conn = connect_to_database('staging')
if conn:
    tables = get_tables(conn)
    print(f"Tables in staging database: {len(tables)}")
    
    for table in tables:
        print(f"\n--- Table: {table} ---")
        columns, row_count = get_table_info(conn, table)
        print(f"Rows: {row_count:,}")
        
        print("Columns:")
        for col in columns:
            pk = " (PRIMARY KEY)" if col[5] else ""
            print(f"  {col[1]} ({col[2]}){pk}")
        
        if row_count > 0:
            print("\nSample data:")
            sample = get_sample_data(conn, table)
            display(sample)
    
    conn.close()
else:
    print("Staging database not found")
# Out:
# Tables in staging database: 2
#
# --- Table: stg_sales_cleaned ---
# Rows: 40,000
# Columns:
#   date_parsed (DATE)
#   customer_id (INTEGER)
#   order_id (INTEGER)
#   sales_amount (REAL)
#   load_timestamp (TIMESTAMP)
#   data_quality_flag (TEXT)
#
# Sample data:
#   date_parsed  customer_id  order_id  sales_amount       load_timestamp  \
# 0  2021-01-01       990787         1        167.72  2025-09-05 20:13:08
# 1  2021-01-01       284871        34        164.37  2025-09-05 20:13:08
# 2  2021-01-01       194576        35        125.67  2025-09-05 20:13:08
# 3  2021-01-01       992731        36        142.25  2025-09-05 20:13:08
# 4  2021-01-01       434276        37        121.01  2025-09-05 20:13:08
#
#   data_quality_flag
# 0             VALID
# 1             VALID
# 2             VALID
# 3             VALID
# 4             VALID
# --- Table: stg_sales_raw ---
# Rows: 40,000
# Columns:
#   unnamed_0 (INTEGER)
#   date_raw (TEXT)
#   customer_id (INTEGER)
#   order_id (INTEGER)
#   sales (REAL)
#   load_timestamp (TIMESTAMP)
#   source_file (TEXT)
#
# Sample data:
#    unnamed_0    date_raw  customer_id  order_id   sales  \
# 0          0  2021-01-01       990787         1  167.72
# 1         33  2021-01-01       284871        34  164.37
# 2         34  2021-01-01       194576        35  125.67
# 3         35  2021-01-01       992731        36  142.25
# 4         36  2021-01-01       434276        37  121.01
#
#                load_timestamp                     source_file
# 0  2025-09-05 16:13:08.768627  HEC_testing_data_sample_2_.csv
# 1  2025-09-05 16:13:08.768627  HEC_testing_data_sample_2_.csv
# 2  2025-09-05 16:13:08.768627  HEC_testing_data_sample_2_.csv
# 3  2025-09-05 16:13:08.768627  HEC_testing_data_sample_2_.csv
# 4  2025-09-05 16:13:08.768627  HEC_testing_data_sample_2_.csv

# %% [markdown]
# ## Warehouse Database (Dimension & Fact Tables)
# Dimensional model optimized for analytics

# %%
conn = connect_to_database('warehouse')
if conn:
    tables = get_tables(conn)
    print(f"Tables in warehouse database: {len(tables)}")
    
    # Separate dimension and fact tables
    dim_tables = [t for t in tables if t.startswith('dim_')]
    fact_tables = [t for t in tables if t.startswith('fact_')]
    other_tables = [t for t in tables if not (t.startswith('dim_') or t.startswith('fact_'))]
    
    # Display dimension tables
    if dim_tables:
        print("\n=== DIMENSION TABLES ===")
        for table in dim_tables:
            print(f"\n--- Table: {table} ---")
            columns, row_count = get_table_info(conn, table)
            print(f"Rows: {row_count:,}")
            
            print("Columns:")
            for col in columns:
                pk = " (PRIMARY KEY)" if col[5] else ""
                print(f"  {col[1]} ({col[2]}){pk}")
            
            if row_count > 0:
                print("\nSample data:")
                sample = get_sample_data(conn, table)
                display(sample)
    
    # Display fact tables
    if fact_tables:
        print("\n=== FACT TABLES ===")
        for table in fact_tables:
            print(f"\n--- Table: {table} ---")
            columns, row_count = get_table_info(conn, table)
            print(f"Rows: {row_count:,}")
            
            print("Columns:")
            for col in columns:
                pk = " (PRIMARY KEY)" if col[5] else ""
                print(f"  {col[1]} ({col[2]}){pk}")
            
            if row_count > 0:
                print("\nSample data:")
                sample = get_sample_data(conn, table)
                display(sample)
    
    # Display other tables
    if other_tables:
        print("\n=== OTHER TABLES ===")
        for table in other_tables:
            print(f"\n--- Table: {table} ---")
            columns, row_count = get_table_info(conn, table)
            print(f"Rows: {row_count:,}")
            
            print("Columns:")
            for col in columns:
                pk = " (PRIMARY KEY)" if col[5] else ""
                print(f"  {col[1]} ({col[2]}){pk}")
            
            if row_count > 0:
                print("\nSample data:")
                sample = get_sample_data(conn, table)
                display(sample)
    
    conn.close()
else:
    print("Warehouse database not found")
# Out:
# Tables in warehouse database: 4
#
# === DIMENSION TABLES ===
#
# --- Table: dim_date ---
# Rows: 685
# Columns:
#   date_id (INTEGER) (PRIMARY KEY)
#   full_date (DATE)
#   year (INTEGER)
#   quarter (INTEGER)
#   month (INTEGER)
#   month_name (TEXT)
#   month_abbr (TEXT)
#   week_of_year (INTEGER)
#   day_of_year (INTEGER)
#   day_of_month (INTEGER)
#   day_of_week (INTEGER)
#   day_name (TEXT)
#   day_abbr (TEXT)
#   is_weekend (INTEGER)
#   is_month_start (INTEGER)
#   is_month_end (INTEGER)
#   is_quarter_start (INTEGER)
#   is_quarter_end (INTEGER)
#   is_year_start (INTEGER)
#   is_year_end (INTEGER)
#   date_string (TEXT)
#   month_year (TEXT)
#   quarter_year (TEXT)
#   created_at (TIMESTAMP)
#
# Sample data:
#     date_id   full_date  year  quarter  month month_name month_abbr  \
# 0  20210101  2021-01-01  2021        1      1    January        Jan
# 1  20210102  2021-01-02  2021        1      1    January        Jan
# 2  20210103  2021-01-03  2021        1      1    January        Jan
# 3  20210104  2021-01-04  2021        1      1    January        Jan
# 4  20210105  2021-01-05  2021        1      1    January        Jan
#
#    week_of_year  day_of_year  day_of_month  ...  is_month_start is_month_end  \
# 0             0            1             1  ...               1            0
# 1             0            2             2  ...               0            0
# 2             0            3             3  ...               0            0
# 3             1            4             4  ...               0            0
# 4             1            5             5  ...               0            0
#
#   is_quarter_start  is_quarter_end  is_year_start  is_year_end  date_string  \
# 0                1               0              1            0   2021-01-01
# 1                0               0              0            0   2021-01-02
# 2                0               0              0            0   2021-01-03
# 3                0               0              0            0   2021-01-04
# 4                0               0              0            0   2021-01-05
#
#    month_year  quarter_year           created_at
# 0        None            Q1  2025-09-05 20:13:08
# 1        None            Q1  2025-09-05 20:13:08
# 2        None            Q1  2025-09-05 20:13:08
# 3        None            Q1  2025-09-05 20:13:08
# 4        None            Q1  2025-09-05 20:13:08
#
# [5 rows x 24 columns]
# --- Table: dim_customer ---
# Rows: 33,477
# Columns:
#   customer_id (INTEGER) (PRIMARY KEY)
#   first_order_date (DATE)
#   last_order_date (DATE)
#   total_transactions (INTEGER)
#   total_spent (REAL)
#   avg_order_value (REAL)
#   total_orders (INTEGER)
#   first_order_cohort_month (TEXT)
#   first_order_cohort_quarter (TEXT)
#   first_order_cohort_year (INTEGER)
#   days_since_first_order (INTEGER)
#   customer_vintage_group (TEXT)
#   days_since_last_order (INTEGER)
#   customer_segment (TEXT)
#   customer_status (TEXT)
#   created_at (TIMESTAMP)
#   updated_at (TIMESTAMP)
#
# Sample data:
#    customer_id first_order_date last_order_date  total_transactions  \
# 0       100001       2021-02-03      2022-11-01                   2
# 1       100041       2021-09-24      2021-09-24                   1
# 2       100155       2021-06-01      2021-06-01                   1
# 3       100178       2021-05-15      2021-05-15                   1
# 4       100184       2021-05-25      2021-11-26                   2
#
#    total_spent  avg_order_value  total_orders first_order_cohort_month  \
# 0       484.83          242.415             2                  2021-02
# 1       229.22          229.220             1                  2021-09
# 2        55.86           55.860             1                  2021-06
# 3        88.17           88.170             1                  2021-05
# 4       370.02          185.010             2                  2021-05
#
#   first_order_cohort_quarter  first_order_cohort_year  days_since_first_order  \
# 0                    2021-Q1                     2021             1675.842465
# 1                    2021-Q3                     2021             1442.842465
# 2                    2021-Q2                     2021             1557.842465
# 3                    2021-Q2                     2021             1574.842465
# 4                    2021-Q2                     2021             1564.842465
#
#   customer_vintage_group days_since_last_order customer_segment  \
# 0       1039.84246527776             365+ days      VIP At Risk
# 1       1442.84246527776             365+ days      VIP At Risk
# 2       1557.84246527776             365+ days   One-Time Buyer
# 3       1574.84246527776             365+ days   One-Time Buyer
# 4       1379.84246527776             365+ days      VIP At Risk
#
#   customer_status           created_at           updated_at
# 0        Inactive  2025-09-05 20:13:09  2025-09-05 20:13:09
# 1        Inactive  2025-09-05 20:13:09  2025-09-05 20:13:09
# 2        Inactive  2025-09-05 20:13:09  2025-09-05 20:13:09
# 3        Inactive  2025-09-05 20:13:09  2025-09-05 20:13:09
# 4        Inactive  2025-09-05 20:13:09  2025-09-05 20:13:09
# --- Table: dim_order ---
# Rows: 40,000
# Columns:
#   order_id (INTEGER) (PRIMARY KEY)
#   customer_id (INTEGER)
#   order_date (DATE)
#   date_id (INTEGER)
#   order_amount (REAL)
#   order_year (INTEGER)
#   order_month (INTEGER)
#   order_quarter (INTEGER)
#   order_day_of_week (INTEGER)
#   order_day_name (TEXT)
#   is_weekend_order (INTEGER)
#   customer_order_sequence (INTEGER)
#   is_first_order (INTEGER)
#   days_since_customer_first_order (INTEGER)
#   days_since_previous_order (INTEGER)
#   order_amount_quartile (TEXT)
#   created_at (TIMESTAMP)
#
# Sample data:
#    order_id  customer_id  order_date   date_id  order_amount  order_year  \
# 0         1       990787  2021-01-01  20210101        167.72        2021
# 1         2       988913  2021-01-01  20210101        217.93        2021
# 2         3       361999  2021-01-01  20210101        124.45        2021
# 3         4       283625  2021-01-01  20210101        190.51        2021
# 4         5       253640  2021-01-01  20210101         72.64        2021
#
#    order_month  order_quarter  order_day_of_week order_day_name  \
# 0            1              1                  6           None
# 1            1              1                  6           None
# 2            1              1                  6           None
# 3            1              1                  6           None
# 4            1              1                  6           None
#
#    is_weekend_order  customer_order_sequence  is_first_order  \
# 0                 0                        1               1
# 1                 0                        1               1
# 2                 0                        1               1
# 3                 0                        1               1
# 4                 0                        1               1
#
#    days_since_customer_first_order days_since_previous_order  \
# 0                                0                      None
# 1                                0                      None
# 2                                0                      None
# 3                                0                      None
# 4                                0                      None
#
#   order_amount_quartile           created_at
# 0           Medium-High  2025-09-05 20:13:09
# 1                  High  2025-09-05 20:13:09
# 2            Medium-Low  2025-09-05 20:13:09
# 3           Medium-High  2025-09-05 20:13:09
# 4                   Low  2025-09-05 20:13:09
# === FACT TABLES ===
#
# --- Table: fact_sales ---
# Rows: 40,000
# Columns:
#   customer_id (INTEGER) (PRIMARY KEY)
#   order_id (INTEGER) (PRIMARY KEY)
#   date_id (INTEGER) (PRIMARY KEY)
#   sales_amount (REAL)
#   transaction_count (INTEGER)
#   created_at (TIMESTAMP)
#
# Sample data:
#    customer_id  order_id   date_id  sales_amount  transaction_count  \
# 0       113769        13  20210101        110.12                  1
# 1       137819        27  20210101        236.52                  1
# 2       140153        53  20210101        319.42                  1
# 3       147613        52  20210101        115.02                  1
# 4       158237         7  20210101         87.72                  1
#
#             created_at
# 0  2025-09-05 20:13:09
# 1  2025-09-05 20:13:09
# 2  2025-09-05 20:13:09
# 3  2025-09-05 20:13:09
# 4  2025-09-05 20:13:09

# %% [markdown]
# ## Business Database (Business Analysis Tables)
# Business insights, analytics, and derived metrics

# %%
conn = connect_to_database('business')
if conn:
    tables = get_tables(conn)
    print(f"Tables in business database: {len(tables)}")
    
    for table in tables:
        print(f"\n--- Table: {table} ---")
        columns, row_count = get_table_info(conn, table)
        print(f"Rows: {row_count:,}")
        
        print("Columns:")
        for col in columns:
            pk = " (PRIMARY KEY)" if col[5] else ""
            print(f"  {col[1]} ({col[2]}){pk}")
        
        if row_count > 0:
            print("\nSample data:")
            sample = get_sample_data(conn, table)
            display(sample)
    
    conn.close()
else:
    print("Business database not found")
# Out:
# Tables in business database: 9
#
# --- Table: monthly_metrics ---
# Rows: 23
# Columns:
#   period_month (TEXT) (PRIMARY KEY)
#   total_sales (REAL)
#   avg_order_value (REAL)
#   total_transactions (INTEGER)
#   total_orders (INTEGER)
#   unique_customers (INTEGER)
#   purchase_frequency (REAL)
#   created_at (TIMESTAMP)
#
# Sample data:
#   period_month  total_sales  avg_order_value  total_transactions  \
# 0      2021-01    279395.61       164.157233                1702
# 1      2021-02    256331.70       165.375290                1550
# 2      2021-03    278361.89       163.549877                1702
# 3      2021-04    281264.62       165.644653                1698
# 4      2021-05    299902.93       171.471086                1749
#
#    total_orders  unique_customers  purchase_frequency           created_at
# 0          1702              1688                1.01  2025-09-05 20:13:09
# 1          1550              1542                1.01  2025-09-05 20:13:09
# 2          1702              1689                1.01  2025-09-05 20:13:09
# 3          1698              1684                1.01  2025-09-05 20:13:09
# 4          1749              1729                1.01  2025-09-05 20:13:09
# --- Table: cohort_analysis ---
# Rows: 276
# Columns:
#   cohort_month (TEXT) (PRIMARY KEY)
#   activity_month (TEXT) (PRIMARY KEY)
#   months_since_acquisition (INTEGER)
#   cohort_size (INTEGER)
#   active_customers (INTEGER)
#   retention_rate_percent (REAL)
#   total_sales (REAL)
#   avg_order_value (REAL)
#
# Sample data:
#   cohort_month activity_month  months_since_acquisition  cohort_size  \
# 0      2021-01        2021-01                         0         1688
# 1      2021-01        2021-02                         1         1688
# 2      2021-01        2021-03                         2         1688
# 3      2021-01        2021-04                         3         1688
# 4      2021-01        2021-05                         4         1688
#
#    active_customers  retention_rate_percent  total_sales  avg_order_value
# 0              1688                  100.00    279395.61       164.157233
# 1                28                    1.66      3842.04       137.215714
# 2                36                    2.13      5909.74       159.722703
# 3                22                    1.30      3154.96       143.407273
# 4                32                    1.90      5815.24       176.219394
# --- Table: customer_ltv_analysis ---
# Rows: 33,477
# Columns:
#   customer_id (INTEGER) (PRIMARY KEY)
#   acquisition_cohort (TEXT)
#   customer_segment (TEXT)
#   total_orders (INTEGER)
#   total_spent (REAL)
#   avg_order_value (REAL)
#   days_active (INTEGER)
#   predicted_ltv_score (INTEGER)
#   churn_risk_score (REAL)
#
# Sample data:
#    customer_id acquisition_cohort customer_segment  total_orders  total_spent  \
# 0       100001            2021-02      VIP At Risk             2       484.83
# 1       100041            2021-09      VIP At Risk             1       229.22
# 2       100155            2021-06   One-Time Buyer             1        55.86
# 3       100178            2021-05   One-Time Buyer             1        88.17
# 4       100184            2021-05      VIP At Risk             2       370.02
#
#    avg_order_value  days_active  predicted_ltv_score  churn_risk_score
# 0          242.415  1675.842465                    1               0.9
# 1          229.220  1442.842465                    1               0.9
# 2           55.860  1557.842465                    1               0.9
# 3           88.170  1574.842465                    1               0.9
# 4          185.010  1564.842465                    1               0.9
# --- Table: campaign_targets ---
# Rows: 28,753
# Columns:
#   customer_id (INTEGER) (PRIMARY KEY)
#   campaign_type (TEXT) (PRIMARY KEY)
#   priority_level (INTEGER)
#   estimated_value (REAL)
#   days_since_last_order (INTEGER)
#   recommended_action (TEXT)
#   created_at (TIMESTAMP)
#
# Sample data:
#    customer_id       campaign_type  priority_level  estimated_value  \
# 0       491584  Long-term Win-back               5          1067.66
# 1       726309  Long-term Win-back               5           972.53
# 2       394105  Long-term Win-back               5           947.46
# 3       203058  Long-term Win-back               5           867.26
# 4       346390  Long-term Win-back               5           815.00
#
#   days_since_last_order          recommended_action           created_at
# 0             365+ days  Final 25% discount attempt  2025-09-05 20:13:32
# 1             365+ days  Final 25% discount attempt  2025-09-05 20:13:32
# 2             365+ days  Final 25% discount attempt  2025-09-05 20:13:32
# 3             365+ days  Final 25% discount attempt  2025-09-05 20:13:32
# 4             365+ days  Final 25% discount attempt  2025-09-05 20:13:32
# --- Table: business_insights ---
# Rows: 6
# Columns:
#   insight_id (TEXT) (PRIMARY KEY)
#   insight_type (TEXT)
#   insight_title (TEXT)
#   insight_description (TEXT)
#   metric_value (REAL)
#   recommendation (TEXT)
#   priority_level (INTEGER)
#   created_at (TIMESTAMP)
#
# Sample data:
#   insight_id  insight_type                      insight_title  \
# 0   CONV_001    CONVERSION           Customer Conversion Rate
# 1    COH_001        COHORT             Best Performing Cohort
# 2    RET_001     RETENTION  Best Retention Cohort Performance
# 3   RISK_001    CHURN_RISK       High-Value Customers at Risk
# 4    SEG_CAN  SEGMENTATION  Cannot Lose Them Segment Analysis
#
#                                  insight_description  metric_value  \
# 0  Out of 33,477 customers, 28,753 (85.89%) are o...         85.89
# 1  Cohort 2021-07 has the highest month-1 retenti...          2.02
# 2  Cohort 2021-01 shows strongest retention: 3m=1...        100.00
# 3  235 high-LTV customers are at risk, representi...        235.00
# 4  16,527 customers (49.4%) in Cannot Lose Them s...         49.40
#
#                                       recommendation  priority_level  \
# 0  Implement automated email sequences to convert...               1
# 1  Analyze and replicate the acquisition strategi...               2
# 2  Analyze acquisition channels and onboarding fo...               1
# 3  Immediate intervention with personalized offer...               1
# 4  Focus on cannot lose them with targeted campaigns               1
#
#             created_at
# 0  2025-09-05 20:13:32
# 1  2025-09-05 20:13:32
# 2  2025-09-05 20:13:32
# 3  2025-09-05 20:13:32
# 4  2025-09-05 20:13:32
# --- Table: customer_lifecycle_snapshot ---
# Rows: 1
# Columns:
#   snapshot_date (DATE) (PRIMARY KEY)
#   lifecycle_stage (TEXT) (PRIMARY KEY)
#   customers (INTEGER)
#   share_of_base (REAL)
#   avg_days_since_last_order (REAL)
#   created_at (TIMESTAMP)
#
# Sample data:
#   snapshot_date lifecycle_stage  customers  share_of_base  \
# 0    2022-11-16        Inactive      33477            1.0
#
#    avg_days_since_last_order           created_at
# 0                      365.0  2025-09-05 20:13:32
# --- Table: cumulative_retention_analysis ---
# Rows: 69
# Columns:
#   cohort_month (TEXT) (PRIMARY KEY)
#   retention_window_months (INTEGER) (PRIMARY KEY)
#   cohort_size (INTEGER)
#   active_customers (INTEGER)
#   cumulative_retention_rate (REAL)
#   avg_purchase_frequency (REAL)
#   total_revenue (REAL)
#   avg_customer_value (REAL)
#   created_at (TIMESTAMP)
#
# Sample data:
#   cohort_month  retention_window_months  cohort_size  active_customers  \
# 0      2021-01                        3         1688              1688
# 1      2021-02                        3         1514              1514
# 2      2021-03                        3         1630              1630
# 3      2021-04                        3         1607              1607
# 4      2021-05                        3         1625              1625
#
#    cumulative_retention_rate  avg_purchase_frequency  total_revenue  \
# 0                      100.0                    1.06      292302.35
# 1                      100.0                    1.06      266411.17
# 2                      100.0                    1.06      284563.90
# 3                      100.0                    1.06      280935.68
# 4                      100.0                    1.05      290916.64
#
#    avg_customer_value           created_at
# 0              173.16  2025-09-05 20:13:09
# 1              175.97  2025-09-05 20:13:09
# 2              174.58  2025-09-05 20:13:09
# 3              174.82  2025-09-05 20:13:09
# 4              179.03  2025-09-05 20:13:09
# --- Table: customer_segmentation ---
# Rows: 33,477
# Columns:
#   customer_id (INTEGER) (PRIMARY KEY)
#   recency_score (INTEGER)
#   frequency_score (INTEGER)
#   monetary_score (INTEGER)
#   rfm_segment (TEXT)
#   segment_description (TEXT)
#   recommended_strategy (TEXT)
#   created_at (TIMESTAMP)
#
# Sample data:
#    customer_id  recency_score  frequency_score  monetary_score  \
# 0       100001              5                2               5
# 1       100041              1                1               4
# 2       100155              1                1               1
# 3       100178              1                1               1
# 4       100184              1                2               5
#
#         rfm_segment                           segment_description  \
# 0     New Customers               Recent customers with potential
# 1  Cannot Lose Them      High-value customers at risk of churning
# 2    Lost Customers  Customers who haven't purchased in long time
# 3    Lost Customers  Customers who haven't purchased in long time
# 4  Cannot Lose Them      High-value customers at risk of churning
#
#                         recommended_strategy           created_at
# 0    Onboarding campaigns, product education  2025-09-05 20:13:32
# 1      Immediate intervention, VIP treatment  2025-09-05 20:13:32
# 2  Win-back campaigns with strong incentives  2025-09-05 20:13:32
# 3  Win-back campaigns with strong incentives  2025-09-05 20:13:32
# 4      Immediate intervention, VIP treatment  2025-09-05 20:13:32
# --- Table: seasonal_trends ---
# Rows: 12
# Columns:
#   period_type (TEXT) (PRIMARY KEY)
#   period_value (TEXT) (PRIMARY KEY)
#   avg_sales (REAL)
#   avg_orders (INTEGER)
#   avg_customers (INTEGER)
#   seasonal_index (REAL)
#   trend_direction (TEXT)
#   created_at (TIMESTAMP)
#
# Sample data:
#   period_type period_value  avg_sales  avg_orders  avg_customers  \
# 0     monthly           01  293816.97        1771           1752
# 1     monthly           02  268193.16        1597           1586
# 2     monthly           03  289289.96        1749           1735
# 3     monthly           04  289618.86        1750           1731
# 4     monthly           05  313485.53        1833           1812
#
#    seasonal_index trend_direction           created_at
# 0           1.007          stable  2025-09-05 20:13:32
# 1           0.919        negative  2025-09-05 20:13:32
# 2           0.992          stable  2025-09-05 20:13:32
# 3           0.993          stable  2025-09-05 20:13:32
# 4           1.075        positive  2025-09-05 20:13:32

# %% [markdown]
# ## Metadata Database (Pipeline Metadata)
# Pipeline execution logs and data quality tracking

# %%
conn = connect_to_database('metadata')
if conn:
    tables = get_tables(conn)
    print(f"Tables in metadata database: {len(tables)}")
    
    for table in tables:
        print(f"\n--- Table: {table} ---")
        columns, row_count = get_table_info(conn, table)
        print(f"Rows: {row_count:,}")
        
        print("Columns:")
        for col in columns:
            pk = " (PRIMARY KEY)" if col[5] else ""
            print(f"  {col[1]} ({col[2]}){pk}")
        
        if row_count > 0:
            print("\nSample data:")
            sample = get_sample_data(conn, table)
            display(sample)
    
    conn.close()
else:
    print("Metadata database not found")
# Out:
# Tables in metadata database: 3
#
# --- Table: pipeline_runs ---
# Rows: 432
# Columns:
#   run_id (TEXT) (PRIMARY KEY)
#   layer (TEXT)
#   table_name (TEXT)
#   status (TEXT)
#   start_time (TIMESTAMP)
#   end_time (TIMESTAMP)
#   row_count (INTEGER)
#   error_message (TEXT)
#
# Sample data:
#                                              run_id      layer  \
# 0      STAGING_stg_sales_raw_20250905_073224_743576    STAGING
# 1  STAGING_stg_sales_cleaned_20250905_073224_828677    STAGING
# 2         WAREHOUSE_dim_date_20250905_073224_860627  WAREHOUSE
# 3     WAREHOUSE_dim_customer_20250905_073224_974817  WAREHOUSE
# 4        WAREHOUSE_dim_order_20250905_073225_084694  WAREHOUSE
#
#           table_name   status                  start_time end_time row_count  \
# 0      stg_sales_raw  STARTED  2025-09-05 07:32:24.743583     None      None
# 1  stg_sales_cleaned  STARTED  2025-09-05 07:32:24.828680     None      None
# 2           dim_date  STARTED  2025-09-05 07:32:24.860633     None      None
# 3       dim_customer  STARTED  2025-09-05 07:32:24.974822     None      None
# 4          dim_order  STARTED  2025-09-05 07:32:25.084703     None      None
#
#   error_message
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# --- Table: data_quality_checks ---
# Rows: 688
# Columns:
#   check_id (TEXT) (PRIMARY KEY)
#   run_id (TEXT)
#   table_name (TEXT)
#   check_type (TEXT)
#   check_name (TEXT)
#   expected_value (TEXT)
#   actual_value (TEXT)
#   status (TEXT)
#   error_details (TEXT)
#   check_time (TIMESTAMP)
#
# Sample data:
#                                             check_id  \
# 0  STAGING_stg_sales_raw_20250905_073224_743576_m...
# 1  STAGING_stg_sales_raw_20250905_073224_743576_c...
# 2  STAGING_stg_sales_raw_20250905_073224_743576_o...
# 3  STAGING_stg_sales_raw_20250905_073224_743576_s...
# 4  STAGING_stg_sales_raw_20250905_073224_743576_c...
#
#                                          run_id     table_name  check_type  \
# 0  STAGING_stg_sales_raw_20250905_073224_743576  stg_sales_raw   ROW_COUNT
# 1  STAGING_stg_sales_raw_20250905_073224_743576  stg_sales_raw  NULL_CHECK
# 2  STAGING_stg_sales_raw_20250905_073224_743576  stg_sales_raw  NULL_CHECK
# 3  STAGING_stg_sales_raw_20250905_073224_743576  stg_sales_raw  NULL_CHECK
# 4  STAGING_stg_sales_raw_20250905_073224_743576  stg_sales_raw  UNIQUENESS
#
#                  check_name expected_value actual_value  status error_details  \
# 0            min_rows_check           1000        40000  PASSED          None
# 1    customer_id_null_check         <=0.0%        0.00%  PASSED          None
# 2       order_id_null_check         <=0.0%        0.00%  PASSED          None
# 3          sales_null_check         <=0.0%        0.00%  PASSED          None
# 4  customer_id_unique_check         >=1000        33477  PASSED          None
#
#                    check_time
# 0  2025-09-05 07:32:24.813365
# 1  2025-09-05 07:32:24.814761
# 2  2025-09-05 07:32:24.816345
# 3  2025-09-05 07:32:24.817772
# 4  2025-09-05 07:32:24.828170
# --- Table: table_lineage ---
# Rows: 0
# Columns:
#   lineage_id (TEXT) (PRIMARY KEY)
#   source_table (TEXT)
#   target_table (TEXT)
#   transformation_type (TEXT)
#   created_at (TIMESTAMP)

# %% [markdown]
# ## Database Summary
# Overview of all tables and row counts

# %%
summary_data = []
total_rows = 0

for db_name, db_path in databases.items():
    if os.path.exists(db_path):
        conn = sqlite3.connect(db_path)
        tables = get_tables(conn)
        
        for table in tables:
            columns, row_count = get_table_info(conn, table)
            summary_data.append({
                'Database': db_name,
                'Table': table,
                'Rows': row_count,
                'Columns': len(columns)
            })
            total_rows += row_count
        
        conn.close()

if summary_data:
    summary_df = pd.DataFrame(summary_data)
    print(f"Total tables: {len(summary_df)}")
    print(f"Total rows across all tables: {total_rows:,}")
    print("\nDetailed summary:")
    display(summary_df)
else:
    print("No tables found in any database")
# Out:
# Total tables: 18
# Total rows across all tables: 291,376
#
# Detailed summary:
#      Database                          Table   Rows  Columns
# 0     staging              stg_sales_cleaned  40000        6
# 1     staging                  stg_sales_raw  40000        7
# 2   warehouse                       dim_date    685       24
# 3   warehouse                   dim_customer  33477       17
# 4   warehouse                      dim_order  40000       17
# 5   warehouse                     fact_sales  40000        6
# 6    business                monthly_metrics     23        8
# 7    business                cohort_analysis    276        8
# 8    business          customer_ltv_analysis  33477        9
# 9    business               campaign_targets  28753        7
# 10   business              business_insights      6        8
# 11   business    customer_lifecycle_snapshot      1        6
# 12   business  cumulative_retention_analysis     69        9
# 13   business          customer_segmentation  33477        8
# 14   business                seasonal_trends     12        8
# 15   metadata                  pipeline_runs    432        8
# 16   metadata            data_quality_checks    688       10
# 17   metadata                  table_lineage      0        5
